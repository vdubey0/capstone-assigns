# %% [markdown]
# # PyTorch & MNIST Intro

# %% [markdown]
# Let's go through a simple example of Pytorch and MNIST as a way to level set NNs and the use of notebooks.

# %%
import torch
import torchvision
import matplotlib.pyplot as pl
random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

# %% [markdown]
# ## Dataset

# %% [markdown]
# MNIST is probably the most traditionally used dataset for neural networks, as it is a relatively challenging problem in computer vision: recognizing single-digit numbers from a hand-written digital format. Classically, this dataset takes the form of samples of $28 \times 28$ matrices.

# %%
batch_size_train = 64
batch_size_test = 1000

# %%
train_loader = torch.utils.data.DataLoader(
    torchvision.datasets.MNIST('./files/', train=True, download=True,
                                transform=torchvision.transforms.Compose([
                                    torchvision.transforms.ToTensor(),
                                    torchvision.transforms.Normalize((0.1307,), (0.3081,))
                                ])),
    batch_size=batch_size_train,
    shuffle=True)

test_loader = torch.utils.data.DataLoader(
    torchvision.datasets.MNIST('./files/', train=False, download=True,
                                transform=torchvision.transforms.Compose([
                                    torchvision.transforms.ToTensor(),
                                    torchvision.transforms.Normalize(
                                        (0.1307,), (0.3081,))
                                ])),
    batch_size=batch_size_test,
    shuffle=True)

# %%
examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

# %%
fig = pl.figure()
for i in range(6):
    pl.subplot(2,3,i+1)
    pl.tight_layout()
    pl.imshow(example_data[i][0], cmap='gray', interpolation='none')
    pl.title("Ground Truth: {}".format(example_targets[i]))
    pl.xticks([])
    pl.yticks([])
pl.show()

# %% [markdown]
# ## Building the model

# %% [markdown]
# We need to specify the model through a Python class. Below we show how to create a Feedforward Neural Network model using Pytorch.

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class FeedforwardNeuralNetModel(nn.Module):
    def __init__(self):
        input_dim = 28*28
        num_classes = 10
        super(FeedforwardNeuralNetModel, self).__init__()
        self.fc1 = nn.Linear(input_dim, num_classes) 

    def forward(self, x):
        out = self.fc1(x)
        return F.log_softmax(out)

# %% [markdown]
# You'll need to instantiate this class as well as an optimizer, which will apply an algorithm to find the internal parameters of that model, such as matrix weights and biases. As an example, we will use the Stochastic Gradient Descent algorithm.

# %%
learning_rate = 0.001
momentum = 0.1
log_interval = 10

# %%
network = FeedforwardNeuralNetModel()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

# %% [markdown]
# ## Training

# %% [markdown]
# Next, we will define the training procedure.

# %%
n_epochs = 5

train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
! mkdir -p results

# %%
def train(epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad() # clears gradients
        output = network(data.reshape(-1, 28*28))
        
        loss = F.nll_loss(output, target)
        loss.backward()
        
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item())
            )
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))
            torch.save(network.state_dict(), f'./results/model_iteration-{epoch}.pth')
            torch.save(optimizer.state_dict(), f'./results/optimizer_iteration-{epoch}.pth')

# %%
train(1)
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.462653
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.314634
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.172709
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.038150
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.011766
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 1.793893
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 1.784094
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.759681
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.595977
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.612938
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.453784
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.386518
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.438524
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.395226
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.237687
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 1.228426
# ...

# %% [markdown]
# <br />
# Alongside training, we will also monitor the performance of the model on a set of samples not seen during the training.

# %%
def test():
    network.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = network(data.reshape(-1, 28*28))
            test_loss += F.nll_loss(output, target, size_average=False).item()
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    test_loss /= len(test_loader.dataset)
    test_losses.append(test_loss)
    print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n' \
          .format(test_loss, correct, len(test_loader.dataset), 100. * correct / len(test_loader.dataset))
    )

# %%
test()
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# /opt/conda/lib/python3.11/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 0.5596, Accuracy: 8696/10000 (87%)

# %% [markdown]
# ## Training and evaluating for multiple epochs

# %% [markdown]
# Let's train now for all desired epochs.

# %%
for epoch in range(2, n_epochs + 1): # starts from the second iteration
  train(epoch)
  test()
# Out:
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.666574
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 2 [640/60000 (1%)]	Loss: 0.541077
# Train Epoch: 2 [1280/60000 (2%)]	Loss: 0.564097
# Train Epoch: 2 [1920/60000 (3%)]	Loss: 0.666229
# Train Epoch: 2 [2560/60000 (4%)]	Loss: 0.488056
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.434858
# Train Epoch: 2 [3840/60000 (6%)]	Loss: 0.543594
# Train Epoch: 2 [4480/60000 (7%)]	Loss: 0.447622
# Train Epoch: 2 [5120/60000 (9%)]	Loss: 0.549790
# Train Epoch: 2 [5760/60000 (10%)]	Loss: 0.652385
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.670172
# Train Epoch: 2 [7040/60000 (12%)]	Loss: 0.586396
# Train Epoch: 2 [7680/60000 (13%)]	Loss: 0.554513
# Train Epoch: 2 [8320/60000 (14%)]	Loss: 0.585009
# Train Epoch: 2 [8960/60000 (15%)]	Loss: 0.654413
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.667827
# ...

# %%
res = {}
res['original'] = test_losses

# %% [markdown]
# # Model performance

# %% [markdown]
# Finally, we can inspect the results.

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %% [markdown]
# It's always important to inspect anecdotes to convince yourself the model is behind as expected.

# %%
with torch.no_grad():
  output = network(example_data.reshape(1000, 28*28))
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)

# %% [markdown]
# **Challenge:** Can you explain why we are using `torch.no_grad()`?
#
# `torch.no_grad()` is disabling the computation of gradients of the network. Calculating the gradients obviously takes time and takes memory to store. When we are evaluating/predicting with the network as we are in the previous cell, there is no need to calculate the gradients because the network has already been trained. So by using `torch.no_grad()`, we are saving time in computation and memory.

# %%
fig = pl.figure()
for i in range(6):
    pl.subplot(2,3,i+1)
    pl.tight_layout()
    pl.imshow(example_data[i][0], cmap='gray', interpolation='none')
    pl.title("Prediction: {}".format(output.data.max(1, keepdim=True)[1][i].item()))
    pl.xticks([])
    pl.yticks([])
fig

# %% [markdown]
# **Challenge:** Re-do the plot above, but showcasing only miss-classifications (i.e. cases in which the model did wrong).

# %%
fig = pl.figure()

num_shown = 0
i = -1
while num_shown < 6:
    i += 1
    prediction = output.data.max(1, keepdim=True)[1][i].item()
    actual = example_targets[i].item()

    if prediction == actual:
        continue
    else:
        num_shown += 1
    
    pl.subplot(2,3,num_shown)
    pl.tight_layout()
    pl.imshow(example_data[i][0], cmap='gray', interpolation='none')
    pl.title("Prediction: {}".format(output.data.max(1, keepdim=True)[1][i].item()))
    pl.xticks([])
    pl.yticks([])
fig

# %% [markdown]
# ## Loading trained models

# %% [markdown]
# Eventually, you will want to load the model you trained in the past for either running inference or continue the training procedure. The functions we developed above save artifacts contain all of the metadata and data about the model, assuming you have the right model class. Let's inspect those files:

# %%
! ls results
# Out:
# model_10p_iteration-1.pth  optimizer_10p_iteration-1.pth
# model_10p_iteration-2.pth  optimizer_10p_iteration-2.pth
# model_10p_iteration-3.pth  optimizer_10p_iteration-3.pth
# model_10p_iteration-4.pth  optimizer_10p_iteration-4.pth
# model_10p_iteration-5.pth  optimizer_10p_iteration-5.pth
# model_iteration-1.pth	   optimizer_iteration-1.pth
# model_iteration-2.pth	   optimizer_iteration-2.pth
# model_iteration-3.pth	   optimizer_iteration-3.pth
# model_iteration-4.pth	   optimizer_iteration-4.pth
# model_iteration-5.pth	   optimizer_iteration-5.pth

# %% [markdown]
# To load a model:

# %%
trained_model = FeedforwardNeuralNetModel()
model_state_dict = torch.load("results/model_iteration-1.pth")
trained_model.load_state_dict(model_state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# Before proceeding, let's inspect `model_state_dict`

# %%
model_state_dict.keys()
# Out:
# odict_keys(['fc1.weight', 'fc1.bias'])

# %%
model_state_dict['fc1.weight'].shape
# Out:
# torch.Size([10, 784])

# %%
f,axs = pl.subplots(3,3, figsize=(8,8))

c = 0
for ax in axs:
    for sax in ax:
        sax.imshow(model_state_dict['fc1.weight'][c].reshape((28,28)), 
                   cmap = pl.get_cmap('Blues'))
        c += 1
        sax.axis('off')

pl.show()

# %% [markdown]
# Let's do the same for the optimizer

# %%
optimizer = optim.SGD(trained_model.parameters(), lr=learning_rate, momentum=momentum)
optimizer_state_dict = torch.load("results/optimizer_iteration-3.pth")
optimizer.load_state_dict(optimizer_state_dict)

# %%
optimizer_state_dict.keys()
# Out:
# dict_keys(['state', 'param_groups'])

# %%
optimizer_state_dict
# Out:
# {'state': {0: {'momentum_buffer': tensor([[-1.3096e-03, -1.3096e-03, -1.3096e-03,  ..., -1.3096e-03,
#             -1.3096e-03, -1.3096e-03],
#            [ 9.4565e-05,  9.4565e-05,  9.4565e-05,  ...,  9.4565e-05,
#              9.4565e-05,  9.4565e-05],
#            [ 7.4225e-03,  7.4225e-03,  7.4225e-03,  ...,  7.4225e-03,
#              7.4225e-03,  7.4225e-03],
#            ...,
#            [-3.4549e-04, -3.4549e-04, -3.4549e-04,  ..., -3.4549e-04,
#             -3.4549e-04, -3.4549e-04],
#            [ 5.1118e-03,  5.1118e-03,  5.1118e-03,  ...,  5.1118e-03,
#              5.1118e-03,  5.1118e-03],
#            [-4.0428e-03, -4.0428e-03, -4.0428e-03,  ..., -4.0428e-03,
#             -4.0428e-03, -4.0428e-03]])},
#   1: {'momentum_buffer': tensor([ 3.0871e-03, -2.2292e-04, -1.7497e-02, -1.0883e-02,  1.6721e-02,
#             3.4194e-05,  1.0465e-02,  8.1442e-04, -1.2050e-02,  9.5301e-03])}},
#  'param_groups': [{'lr': 0.001,
#    'momentum': 0.1,
#    'dampening': 0,
# ...

# %% [markdown]
# **Challenge:** Can you make sense of the data in this dictionary?
#
# This dictionary contains the information about the optimizer for the third iteration. 'state' contains a dictionary about the information for each parameter. From what I understand, 'momentum_buffer' is an accumulation of the gradients for a specific parameter so that it can be used for better future updates. Since we are looking at the state_dict for the third iteration, we only have this information for the previous two iterations. 'param_groups' gives the hyperparameters for the optimizer including learning_rate, momentum, etc.

# %% [markdown]
# ## Final challenges
#
# * What happens if you use only 10% of the available training data? Plot the difference in performance of the network.
# * What happens if you remove 80% of all samples with label 5. Do you see a difference in performance? Is this difference homogeneous?
# * What happens if you change parameters like the learnign rate and momentum? Plot the difference.
# * Can you add more layers to this neural network? Start with one additional layer (often called "hidden layer"). What changes can you observe in doing so?
# * Can you add regularization to this model? Look for L1, L2, and drop-out regularizations. What changes do you observe?
# * [stretch] Can you change this model and turn it into a convolutional neural network?

# %% [markdown]
# What happens if you use only 10% of the available training data? Plot the difference in performance of the network.
#
# I would expect the performance of the network to decrease. The performance of a model typically increases the more data you give it because it has more examples to learn from. If 90% of the data is removed, the model has much less examples to learn from and thus cannot generalize well enough to unseen data.

# %%
network = FeedforwardNeuralNetModel()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

n_epochs = 5
num_batches = int(len(train_loader) * 0.1)

train_losses = []
train_counter = []
test_losses = []
test_counter = [i*num_batches * batch_size_train for i in range(n_epochs + 1)]

def train_10_percent(epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if batch_idx >= num_batches:
            break
        
        optimizer.zero_grad() # clears gradients
        output = network(data.reshape(-1, 28*28))
        
        loss = F.nll_loss(output, target)
        loss.backward()
        
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), num_batches * batch_size_train,
                100. * batch_idx / num_batches, loss.item())
            )
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*num_batches * batch_size_train))
            torch.save(network.state_dict(), f'./results/model_10p_iteration-{epoch}.pth')
            torch.save(optimizer.state_dict(), f'./results/optimizer_10p_iteration-{epoch}.pth')

# %%
for epoch in range(1, n_epochs + 1):
  train_10_percent(epoch)
  test()
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/5952 (0%)]	Loss: 2.341127
# Train Epoch: 1 [640/5952 (11%)]	Loss: 2.193309
# Train Epoch: 1 [1280/5952 (22%)]	Loss: 2.058556
# Train Epoch: 1 [1920/5952 (32%)]	Loss: 2.019354
# Train Epoch: 1 [2560/5952 (43%)]	Loss: 1.925209
# Train Epoch: 1 [3200/5952 (54%)]	Loss: 1.825863
# Train Epoch: 1 [3840/5952 (65%)]	Loss: 1.706770
# Train Epoch: 1 [4480/5952 (75%)]	Loss: 1.707325
# Train Epoch: 1 [5120/5952 (86%)]	Loss: 1.512980
# Train Epoch: 1 [5760/5952 (97%)]	Loss: 1.461941
#
# Test set: Avg. loss: 1.4905, Accuracy: 6452/10000 (65%)
#
# Train Epoch: 2 [0/5952 (0%)]	Loss: 1.503312
# Train Epoch: 2 [640/5952 (11%)]	Loss: 1.441326
# Train Epoch: 2 [1280/5952 (22%)]	Loss: 1.509312
# Train Epoch: 2 [1920/5952 (32%)]	Loss: 1.426104
# Train Epoch: 2 [2560/5952 (43%)]	Loss: 1.414077
# ...

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %% [markdown]
# The performance of the network is much worse when we only use 10% of the data. The accuracy with the whole dataset is 90% vs 83% when we dropped 90% of the data. However, since there is much less data, the network trains a lot faster.

# %% [markdown]
# What happens if you remove 80% of all samples with label 5. Do you see a difference in performance? Is this difference homogeneous?
#
# Again, we should see a drop in performance. However, we should see this performance dip mostly in predicting data with label 5. This is because the model does not know well enough was a 5 would look like.

# %%
import numpy as np

train_dataset = train_loader.dataset

all_indices = np.arange(len(train_dataset))
label_5_indices = [i for i, (img, label) in enumerate(train_dataset) if label == 5]
num_to_remove = int(0.80 * len(label_5_indices))
remove_indices = np.random.choice(label_5_indices, size=num_to_remove, replace=False)
remaining_indices = np.setdiff1d(all_indices, remove_indices)
train_dataset_subset = torch.utils.data.Subset(train_dataset, remaining_indices)
train_loader_filtered = torch.utils.data.DataLoader(train_dataset_subset, batch_size=batch_size_train, shuffle=True)

# %%
network = FeedforwardNeuralNetModel()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

n_epochs = 5

train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader_filtered.dataset) for i in range(n_epochs + 1)]

def train_filtered(epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader_filtered):
        optimizer.zero_grad() # clears gradients
        output = network(data.reshape(-1, 28*28))
        
        loss = F.nll_loss(output, target)
        loss.backward()
        
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader_filtered.dataset),
                100. * batch_idx / len(train_loader_filtered), loss.item())
            )
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader_filtered.dataset)))

# %%
for epoch in range(1, n_epochs + 1):
  train_filtered(epoch)
  test()
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/55664 (0%)]	Loss: 2.685915
# Train Epoch: 1 [640/55664 (1%)]	Loss: 2.289705
# Train Epoch: 1 [1280/55664 (2%)]	Loss: 2.391660
# Train Epoch: 1 [1920/55664 (3%)]	Loss: 2.044316
# Train Epoch: 1 [2560/55664 (5%)]	Loss: 1.957131
# Train Epoch: 1 [3200/55664 (6%)]	Loss: 1.812485
# Train Epoch: 1 [3840/55664 (7%)]	Loss: 1.696425
# Train Epoch: 1 [4480/55664 (8%)]	Loss: 1.661029
# Train Epoch: 1 [5120/55664 (9%)]	Loss: 1.627279
# Train Epoch: 1 [5760/55664 (10%)]	Loss: 1.382209
# Train Epoch: 1 [6400/55664 (11%)]	Loss: 1.600829
# Train Epoch: 1 [7040/55664 (13%)]	Loss: 1.312180
# Train Epoch: 1 [7680/55664 (14%)]	Loss: 1.346319
# Train Epoch: 1 [8320/55664 (15%)]	Loss: 1.420785
# Train Epoch: 1 [8960/55664 (16%)]	Loss: 1.264034
# Train Epoch: 1 [9600/55664 (17%)]	Loss: 1.464174
# ...

# %%
correct_per_label = torch.zeros(10)
total_per_label = torch.zeros(10)

with torch.no_grad():
    for data, target in test_loader:
        output = network(data.reshape(-1, 28*28))
        pred = output.data.max(1, keepdim=True)[1]

        for i in range(10):
            only_one_label = (target == i)
            total_per_label[i] += only_one_label.sum().item()
            correct_per_label[i] += (pred[only_one_label] == i).sum().item()

accuracy_per_label = correct_per_label / total_per_label
# Out:
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)

# %%
pl.bar(np.arange(0, 10), accuracy_per_label)
pl.xticks(np.arange(0, 10))
pl.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# The accuracy for each label is homogenuous except for label 5. For predicting label 5, we see a huge drop in performance when compared to the other labels. This is expected because we did not give the model much data as to what '5' looks like.

# %% [markdown]
# What happens if you change parameters like the learning rate and momentum? Plot the difference.

# %%
learning_rates = [0.001, 0.01, 0.1] 
momentum = 0.1
res_lrs = {}

n_epochs = 5

final_training_losses = []
final_test_losses = []

for learning_rate in learning_rates:
    train_losses = []
    train_counter = []
    test_losses = []
    test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]
    
    network = FeedforwardNeuralNetModel()
    optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

    print(f'LEARNING RATE = {learning_rate}')
    for epoch in range(1, n_epochs + 1):
      train(epoch)
      test()

    res_lrs[learning_rate] = test_losses

    final_training_losses.append(tuple([train_counter, train_losses]))
# Out:
# LEARNING RATE = 0.001
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.338261
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.298072
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.117948
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.036092
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.010071
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 1.864799
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 1.766007
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.659429
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.566938
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.534500
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.530213
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.489605
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.391134
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.366500
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.288732
# ...

# %%
pl.figure(figsize=(10, 10))
for i, (lrs, losses) in enumerate(final_training_losses):
    pl.plot(lrs, losses, alpha=0.7, label=f'Learning Rate = {learning_rates[i]}')
pl.legend()

# %%
pl.scatter(test_counter[:-1], res_lrs[0.001], color='red', label='LR = 0.001')
pl.plot(test_counter[:-1], res_lrs[0.001], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res_lrs[0.01], color='blue', label='LR = 0.01')
pl.plot(test_counter[:-1], res_lrs[0.01], linestyle='--', color='blue')

pl.scatter(test_counter[:-1], res_lrs[0.1], color='green', label='LR = 0.1')
pl.plot(test_counter[:-1], res_lrs[0.1], linestyle='--', color='green')

pl.legend()
pl.title('Test Loss by Learning Rate')
pl.show()

# %% [markdown]
# From the training loss graph above, we can see that when learning rate increases, the loss decreases much less predictably throughout iterations/epochs. For the lowest learning rate (in blue), the spikes in the graph are much less profound than the spikes in green. However, it is worth noting that at the end of 5 epochs, the lowest learning rate performed the worst on the test set. However, this makes sense because since the learning rate is so small, it would probably take more iterations/epochs than currently to converge to a lower accuracy. The higher learning rates may fail to converge to the lowest achievable accuracy.

# %%
learning_rate = 0.001
momentums = [0.01, 0.1, 1]
res_moms = {}

n_epochs = 5

final_training_losses = []
final_test_losses = []

for mm in momentums:
    train_losses = []
    train_counter = []
    test_losses = []
    test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]
    
    network = FeedforwardNeuralNetModel()
    optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=mm)

    print(f'MOMENTUM = {mm}')
    for epoch in range(1, n_epochs + 1):
      train(epoch)
      test()

    res_moms[mm] = test_losses

    final_training_losses.append(tuple([train_counter, train_losses]))
# Out:
# MOMENTUM = 0.01
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.375015
# /tmp/ipykernel_320/3418281087.py:10: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.343432
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.192700
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.060180
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 1.910115
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 1.910723
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.007554
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 1.781698
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 1.592029
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 1.502828
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 1.517686
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 1.587815
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 1.540128
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 1.413009
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 1.343146
# ...

# %%
pl.figure(figsize=(10, 10))
for i, (lrs, losses) in enumerate(final_training_losses):
    pl.plot(lrs, losses, alpha=0.7, label=f'Momentum = {momentums[i]}')
pl.legend()
pl.title('Training Loss')
# Out:
# Text(0.5, 1.0, 'Training Loss')

# %%
pl.scatter(test_counter[:-1], res_moms[0.01], color='red', label='Mom = 0.01')
pl.plot(test_counter[:-1], res_moms[0.01], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res_moms[0.1], color='blue', label='Mom = 0.1')
pl.plot(test_counter[:-1], res_moms[0.1], linestyle='--', color='blue')

pl.scatter(test_counter[:-1], res_moms[1], color='green', label='Mom = 1')
pl.plot(test_counter[:-1], res_moms[1], linestyle='--', color='green')

pl.legend()
pl.title('Test Loss by Momentum')
pl.show()

# %% [markdown]
# From the graphs above in the green line, we can see that vastly increasing momentum creates bad performance. The training loss is never able to converge and the test loss just keeps increasing as the iterations increase.

# %% [markdown]
# Can you add more layers to this neural network? Start with one additional layer (often called "hidden layer"). What changes can you observe in doing so?

# %%
class FeedforwardNeuralNetModelHiddenLayer(nn.Module):
    def __init__(self):
        input_dim = 28*28
        num_classes = 10
        hidden_dim = 256
        
        super(FeedforwardNeuralNetModelHiddenLayer, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.sigmoid = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.sigmoid(out)
        out = self.fc2(out)
        
        return F.log_softmax(out)

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

learning_rate = 0.001
momentum = 0.1

network = FeedforwardNeuralNetModelHiddenLayer()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

for epoch in range(1, n_epochs+1):
    train(epoch)
    test()

res['hidden_layer'] = test_losses
# Out:
# /tmp/ipykernel_320/1161000428.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.360144
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.290612
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.290501
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.208070
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.199215
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.180642
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.136735
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.179026
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.105231
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.095154
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.103305
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 2.134090
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 2.076918
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 2.059978
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.049930
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 2.073987
# ...

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %%
pl.scatter(test_counter[:-1], res['original'], color='red', label='Orignal Network')
pl.plot(test_counter[:-1], res['original'], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res['hidden_layer'], color='blue', label='With Hidden Layer')
pl.plot(test_counter[:-1], res['hidden_layer'], linestyle='--', color='blue')

pl.legend()
pl.title('Test Loss')
pl.show()

# %% [markdown]
# Adding an extra layer to the model doesn't really improve performance after training 5 epochs. We can see that in the above graph that the final test accuracies are pretty similar - the simpler network actually outperforms the one with the hidden layer. One reason for this is that adding an extra layer greatly increases the amount of parameters to be learned. 5 epochs may not be enough for the parameters in the network to converge to their optimal values.

# %% [markdown]
# Can you add regularization to this model? Look for L1, L2, and drop-out regularizations. What changes do you observe?

# %%
def train_l1(epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad() # clears gradients
        output = network(data.reshape(-1, 28*28))
        
        loss = F.nll_loss(output, target)
        
        l1_norm = 0
        lambda_l1 = 0.001
        for param in network.parameters():
            l1_norm += torch.sum(torch.abs(param))
        loss += lambda_l1 * l1_norm
        
        loss.backward()
        
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item())
            )
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

learning_rate = 0.001
momentum = 0.1

network = FeedforwardNeuralNetModelHiddenLayer()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

for epoch in range(1, n_epochs + 1):
    train_l1(epoch)
    test()

res['l1'] = test_losses
# Out:
# /tmp/ipykernel_320/1161000428.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 5.999537
# Train Epoch: 1 [640/60000 (1%)]	Loss: 5.936497
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 5.946629
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 5.924795
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 5.908068
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 5.839859
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 5.862053
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 5.846727
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 5.824827
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 5.781992
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 5.799668
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 5.751528
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 5.746371
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 5.724233
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 5.652715
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 5.621441
# ...

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %%
pl.scatter(test_counter[:-1], res['l1'], color='red', label='L1 Regularization')
pl.plot(test_counter[:-1], res['l1'], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res['hidden_layer'], color='blue', label='With Hidden Layer')
pl.plot(test_counter[:-1], res['hidden_layer'], linestyle='--', color='blue')

pl.legend()
pl.title('Test Loss')
pl.show()

# %%
def train_l2(epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad() # clears gradients
        output = network(data.reshape(-1, 28*28))
        
        loss = F.nll_loss(output, target)
        
        l2_norm = 0
        lambda_l2 = 0.01
        for param in network.parameters():
            l2_norm += torch.sum(torch.square(param))
        loss += lambda_l2 * l2_norm
        
        loss.backward()
        
        optimizer.step()
        
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item())
            )
            train_losses.append(loss.item())
            train_counter.append((batch_idx*64) + ((epoch-1)*len(train_loader.dataset)))
            torch.save(network.state_dict(), f'./results/model_iteration-{epoch}.pth')
            torch.save(optimizer.state_dict(), f'./results/optimizer_iteration-{epoch}.pth')

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

learning_rate = 0.001
momentum = 0.1

network = FeedforwardNeuralNetModelHiddenLayer()
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

for epoch in range(1, n_epochs + 1):
    train_l2(epoch)
    test()

res['l2'] = test_losses
# Out:
# /tmp/ipykernel_320/1161000428.py:17: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 3.231967
# Train Epoch: 1 [640/60000 (1%)]	Loss: 3.201225
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 3.174799
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 3.177712
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 3.153616
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 3.102822
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 3.076933
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 3.128120
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 3.085058
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 3.024837
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 3.012475
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 2.975829
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 2.959925
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 2.942646
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.935781
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 2.885118
# ...

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %%
pl.scatter(test_counter[:-1], res['l1'], color='red', label='L1 Regularization')
pl.plot(test_counter[:-1], res['l1'], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res['hidden_layer'], color='blue', label='No Regularization')
pl.plot(test_counter[:-1], res['hidden_layer'], linestyle='--', color='blue')

pl.scatter(test_counter[:-1], res['l2'], color='green', label='L2 Regularization')
pl.plot(test_counter[:-1], res['l2'], linestyle='--', color='green')

pl.legend()
pl.title('Test Loss')
pl.show()

# %%
class FeedforwardNeuralNetModelDropout(nn.Module):
    def __init__(self, dropout_rate):
        input_dim = 28*28
        num_classes = 10
        hidden_dim = 256
        
        super(FeedforwardNeuralNetModelDropout, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.sigmoid = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout_rate)
        self.fc2 = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.sigmoid(out)
        out = self.dropout(out)
        out = self.fc2(out)
        
        return F.log_softmax(out)

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

learning_rate = 0.001
momentum = 0.1

network = FeedforwardNeuralNetModelDropout(dropout_rate = 0.2)
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

for epoch in range(1, n_epochs + 1):
    train(epoch)
    test()

res['dropout_0.2'] = test_losses
# Out:
# /tmp/ipykernel_320/3565405704.py:19: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.339492
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.283851
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.317333
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.244094
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.200469
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.199224
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.176836
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.148511
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.151387
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.118404
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.069093
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 2.111851
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 2.026689
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 2.019389
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.031123
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 2.019052
# ...

# %%
fig = pl.figure()
pl.plot(train_counter, train_losses, color=(0.2, 0.2, 1.0))
pl.scatter(test_counter[:-1], test_losses, color=(1.0, 0.2, 0.2))

pl.legend(['Train Loss', 'Test Loss'], loc='upper right', frameon=False)
pl.xlabel('Training Samples')
pl.ylabel('Log Likelihood Loss')

pl.show()

# %%
train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

learning_rate = 0.001
momentum = 0.1

network = FeedforwardNeuralNetModelDropout(dropout_rate = 0.1)
optimizer = optim.SGD(network.parameters(), lr=learning_rate, momentum=momentum)

for epoch in range(1, n_epochs + 1):
    train(epoch)
    test()

res['dropout_0.1'] = test_losses
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.280513
# /tmp/ipykernel_320/3565405704.py:19: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Train Epoch: 1 [640/60000 (1%)]	Loss: 2.277074
# Train Epoch: 1 [1280/60000 (2%)]	Loss: 2.263413
# Train Epoch: 1 [1920/60000 (3%)]	Loss: 2.244354
# Train Epoch: 1 [2560/60000 (4%)]	Loss: 2.267644
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 2.197229
# Train Epoch: 1 [3840/60000 (6%)]	Loss: 2.167983
# Train Epoch: 1 [4480/60000 (7%)]	Loss: 2.189747
# Train Epoch: 1 [5120/60000 (9%)]	Loss: 2.074777
# Train Epoch: 1 [5760/60000 (10%)]	Loss: 2.160692
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 2.083595
# Train Epoch: 1 [7040/60000 (12%)]	Loss: 2.061100
# Train Epoch: 1 [7680/60000 (13%)]	Loss: 2.068942
# Train Epoch: 1 [8320/60000 (14%)]	Loss: 2.020233
# Train Epoch: 1 [8960/60000 (15%)]	Loss: 2.083877
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 2.012478
# ...

# %%
pl.scatter(test_counter[:-1], res['l1'], color='red', label='L1 Regularization')
pl.plot(test_counter[:-1], res['l1'], linestyle='--', color='red')

pl.scatter(test_counter[:-1], res['hidden_layer'], color='blue', label='No Regularization')
pl.plot(test_counter[:-1], res['hidden_layer'], linestyle='--', color='blue')

pl.scatter(test_counter[:-1], res['l2'], color='green', label='L2 Regularization')
pl.plot(test_counter[:-1], res['l2'], linestyle='--', color='green')

pl.scatter(test_counter[:-1], res['dropout_0.2'], color='black', label='Dropout = 0.2')
pl.plot(test_counter[:-1], res['dropout_0.2'], linestyle='--', color='black')

pl.scatter(test_counter[:-1], res['dropout_0.1'], color='purple', label='Dropout = 0.1')
pl.plot(test_counter[:-1], res['dropout_0.1'], linestyle='--', color='purple')

pl.legend()
pl.title('Test Loss')
pl.show()

# %% [markdown]
# None of the models with regularizations beat the original model without regularization - however the models did come very close. For dropout, I tested two hyperparameters - dropout at 0.2 and 0.1. I believe that maybe by performing some more hyperparameter tuning on this parameter, we could potentially beat the non-regularized model. Even for the l1 and l2 models, tuning the strength of regularization parameter could lead to better performance. Currently, it is at a fixed value of 0.01.
